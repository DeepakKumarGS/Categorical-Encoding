# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from tqdm import tqdm
import random

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
## read the data:
kaggle=0

if kaggle==1:
    
    train=pd.read_csv("/kaggle/input/cat-in-the-dat/train.csv")
    test=pd.read_csv("/kaggle/input/cat-in-the-dat/test.csv")
    sample=pd.read_csv("/kaggle/input/cat-in-the-dat/sample_submission.csv")
    
else:
    train=pd.read_csv("train.csv")
    test=pd.read_csv("test.csv")
    sample=pd.read_csv("sample_submission.csv")

# %%
train.head()

# %%
train.dtypes

# %%
train.isnull().any(),test.isnull().any()

# %% [markdown]
# We dont have any null vales in the dataset.

# %%
for c in train.columns :
    if c not in ['id','target']:
        print(c,"has",train[c].nunique(),"unique values\n")

# %% [markdown]
# nom_5,nom_6,nom_7,nom_8,nom_9 has more cardinality compared to other variables.Lets check if there exist any unique values in test set for these columns.

# %%
for col in ['nom_5','nom_6','nom_7','nom_8','nom_9']:
    print(col,"has ",set(train[col].unique())-set(test[col].unique())," unique value in train set not available in test dataset\n")

# %% [markdown]
# From the result we understand that nom_7,nom_8 and nom_9 have values which are not present in the test dataset.The local CV score without removing these variable is 0.79910 .

# %% [markdown]
# Now we will start experimenting with different encoding techniques.I will use the techniques described in this [kaggle course](https://www.kaggle.com/matleonard/categorical-encodings)

# %%
train.shape,test.shape

# %%
eda_cols=[col for col in train.columns if col not in ['day','month','id','target']]

## We find from the model importance that nom_5 ,nom_6,nom_7,nom_8 and ord_5 are good predictors of target.We try out the summary aggregation only for those features.
eda_cols=['nom_5','nom_6','nom_7','nom_8','ord_5']

# %%
for col in eda_cols:
            new_col=col+'_month_count'
            print(f'\n Creating new column for {col} and train dataset')
            temp_dict=train.groupby([col,'month'])['month'].agg(['count']).reset_index().rename({'month':'month','bin_0':col,'count':new_col},axis=1)
            train=pd.merge(train,temp_dict,how='left',on=[col,'month'])
            
for col in eda_cols:
            new_col=col+'_month_count'
            print(f'\n Creating new column for {col} and test dataset')
            temp_dict=test.groupby([col,'month'])['month'].agg(['count']).reset_index().rename({'month':'month','bin_0':col,'count':new_col},axis=1)
            
            test=pd.merge(test,temp_dict,how='left',on=[col,'month'])
# Out:
#  Creating new column for nom_5 and train dataset
#
#  Creating new column for nom_6 and train dataset
#
#  Creating new column for nom_7 and train dataset
#
#  Creating new column for nom_8 and train dataset
#
#  Creating new column for ord_5 and train dataset
#
#  Creating new column for nom_5 and test dataset
#
#  Creating new column for nom_6 and test dataset
#
#  Creating new column for nom_7 and test dataset
#
#  Creating new column for nom_8 and test dataset
#
#  Creating new column for ord_5 and test dataset

# %%
train.columns,test.columns
# Out:
# (Index(['id', 'bin_0', 'bin_1', 'bin_2', 'bin_3', 'bin_4', 'nom_0', 'nom_1',
#         'nom_2', 'nom_3', 'nom_4', 'nom_5', 'nom_6', 'nom_7', 'nom_8', 'nom_9',
#         'ord_0', 'ord_1', 'ord_2', 'ord_3', 'ord_4', 'ord_5', 'day', 'month',
#         'target', 'nom_5_month_count', 'nom_6_month_count', 'nom_7_month_count',
#         'nom_8_month_count', 'ord_5_month_count'],
#        dtype='object'),
#  Index(['id', 'bin_0', 'bin_1', 'bin_2', 'bin_3', 'bin_4', 'nom_0', 'nom_1',
#         'nom_2', 'nom_3', 'nom_4', 'nom_5', 'nom_6', 'nom_7', 'nom_8', 'nom_9',
#         'ord_0', 'ord_1', 'ord_2', 'ord_3', 'ord_4', 'ord_5', 'day', 'month',
#         'nom_5_month_count', 'nom_6_month_count', 'nom_7_month_count',
#         'nom_8_month_count', 'ord_5_month_count'],
#        dtype='object'))

# %% [markdown]
# ## Experiement 1:

# %% [markdown]
# Our strategy is to one hot encode the binary categorical variables - bin_0 to bin_4,ordinal variables ord_0 to ord_2 , target encode the rest.Before that , lets create new features combining ord and nom features as below.This is done after several iterations of observation in feature importance and these features perform individually well.So I try to see whether the interaction gives much better results.

# %%
## Creating new features after doing one round of training and understanding the gini importance

# train['ord_1'+'_'+'ord_5']=train['ord_1']+"_"+train['ord_5']
# test['ord_1'+'_'+'ord_5']=test['ord_1']+"_"+test['ord_5']

# train['ord_1'+'_'+'ord_2']=train['ord_1']+"_"+train['ord_2']
# test['ord_1'+'_'+'ord_2']=test['ord_1']+"_"+test['ord_2']

# train['nom_6'+'_'+'nom_7']=train['nom_6']+'_'+train['nom_7']
# test['nom_6'+'_'+'nom_7']=test['nom_6']+'_'+test['nom_7']

# %%
# a=train
# b=test

# %%
## OHE columns with less cardinality

cat_cols=['bin_0','bin_1','bin_2','bin_3','bin_4','ord_0','ord_1','ord_2']
#https://github.com/rushter/heamy/blob/c330854cee3c547417eb353a4a4a23331b40b4bc/heamy/feature.py

for column in cat_cols:
      
        cate = pd.concat([train[column], test[column]]).dropna().unique()

        train[column] = train[column].astype('category')
        test[column] = test[column].astype('category')

train = pd.get_dummies(train, columns=cat_cols, dummy_na=False, sparse=False)
test = pd.get_dummies(test, columns=cat_cols, dummy_na=False, sparse=False)

# %%
train.columns,test.columns
# Out:
# (Index(['id', 'nom_0', 'nom_1', 'nom_2', 'nom_3', 'nom_4', 'nom_5', 'nom_6',
#         'nom_7', 'nom_8', 'nom_9', 'ord_3', 'ord_4', 'ord_5', 'day', 'month',
#         'target', 'nom_5_month_count', 'nom_6_month_count', 'nom_7_month_count',
#         'nom_8_month_count', 'ord_5_month_count', 'bin_0_0', 'bin_0_1',
#         'bin_1_0', 'bin_1_1', 'bin_2_0', 'bin_2_1', 'bin_3_F', 'bin_3_T',
#         'bin_4_N', 'bin_4_Y', 'ord_0_1', 'ord_0_2', 'ord_0_3',
#         'ord_1_Contributor', 'ord_1_Expert', 'ord_1_Grandmaster',
#         'ord_1_Master', 'ord_1_Novice', 'ord_2_Boiling Hot', 'ord_2_Cold',
#         'ord_2_Freezing', 'ord_2_Hot', 'ord_2_Lava Hot', 'ord_2_Warm'],
#        dtype='object'),
#  Index(['id', 'nom_0', 'nom_1', 'nom_2', 'nom_3', 'nom_4', 'nom_5', 'nom_6',
#         'nom_7', 'nom_8', 'nom_9', 'ord_3', 'ord_4', 'ord_5', 'day', 'month',
#         'nom_5_month_count', 'nom_6_month_count', 'nom_7_month_count',
#         'nom_8_month_count', 'ord_5_month_count', 'bin_0_0', 'bin_0_1',
#         'bin_1_0', 'bin_1_1', 'bin_2_0', 'bin_2_1', 'bin_3_F', 'bin_3_T',
#         'bin_4_N', 'bin_4_Y', 'ord_0_1', 'ord_0_2', 'ord_0_3',
#         'ord_1_Contributor', 'ord_1_Expert', 'ord_1_Grandmaster',
#         'ord_1_Master', 'ord_1_Novice', 'ord_2_Boiling Hot', 'ord_2_Cold',
#         'ord_2_Freezing', 'ord_2_Hot', 'ord_2_Lava Hot', 'ord_2_Warm'],
#        dtype='object'))

# %%
import category_encoders as ce

# %%
def frequency_encoding(variable):
    t = train[variable].value_counts().reset_index()
    t = t.reset_index()
    t.loc[t[variable] == 1, 'level_0'] = np.nan
    t.set_index('index', inplace=True)
    max_label = t['level_0'].max() + 1
    t.fillna(max_label, inplace=True)
    return t.to_dict()['level_0']

# %%
# temp = test['nom_6_nom_7'].value_counts().reset_index()
# temp = temp.reset_index()
# temp.loc[temp['nom_6_nom_7'] == 1, 'level_0'] = np.nan
# temp.set_index('index', inplace=True)
# max_label = temp['level_0'].max() + 1
# temp.fillna(max_label, inplace=True)
# #temp.to_dict()['level_0'],max_label
# temp.isna().any()

# %%
#ce_cols=['nom_0','nom_1','nom_2','nom_3','nom_4','nom_5','nom_6','nom_7','nom_8', 'nom_9', 'ord_3', 'ord_4', 'ord_5', 'day', 'month','ord_1_ord_5', 'ord_1_ord_2','nom_6_nom_7']
## Remove day,month and newly created combined columns:
ce_cols=['nom_0','nom_1','nom_2','nom_3','nom_4','nom_5','nom_6','nom_7','nom_8', 'nom_9', 'ord_3', 'ord_4', 'ord_5']
## Remove cols that have been summarised earlier:
ce_cols = [c for c in ce_cols if c not in eda_cols]

# %%
ce_cols
# Out:
# ['nom_0', 'nom_1', 'nom_2', 'nom_3', 'nom_4', 'nom_9', 'ord_3', 'ord_4']

# %%
# cat_boost=ce.CatBoostEncoder(cols=ce_cols)
# cat_boost.fit(train[ce_cols],train['target'])

# train=train.join(cat_boost.transform(train[ce_cols]).add_suffix('_cb'))
# test=test.join(cat_boost.transform(test[ce_cols]).add_suffix('_cb'))

# %%
## Frequency encode variables:
for variable in tqdm(ce_cols):
    freq_encod_dict=frequency_encoding(variable)
    train[variable+'_FE']=train[variable].map(lambda x:freq_encod_dict.get(x,1))# return value as 1 if the variable does not exist in freq_encod_dict
    test[variable+'_FE']=test[variable].map(lambda x:freq_encod_dict.get(x,1))
    #categorical_columns.remove(variable)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:03<00:00,  2.31it/s]

# %%
# cat_cols=['bin_0','bin_1','bin_2','bin_3','bin_4','ord_0','ord_1','ord_2']
# #https://github.com/rushter/heamy/blob/c330854cee3c547417eb353a4a4a23331b40b4bc/heamy/feature.py

# for column in cat_cols:
      
#         cate = pd.concat([train[column], test[column]]).dropna().unique()

#         train[column] = train[column].astype('category')
#         test[column] = test[column].astype('category')

# %%
train.columns,test.columns
# Out:
# (Index(['id', 'nom_0', 'nom_1', 'nom_2', 'nom_3', 'nom_4', 'nom_5', 'nom_6',
#         'nom_7', 'nom_8', 'nom_9', 'ord_3', 'ord_4', 'ord_5', 'day', 'month',
#         'target', 'nom_5_month_count', 'nom_6_month_count', 'nom_7_month_count',
#         'nom_8_month_count', 'ord_5_month_count', 'bin_0_0', 'bin_0_1',
#         'bin_1_0', 'bin_1_1', 'bin_2_0', 'bin_2_1', 'bin_3_F', 'bin_3_T',
#         'bin_4_N', 'bin_4_Y', 'ord_0_1', 'ord_0_2', 'ord_0_3',
#         'ord_1_Contributor', 'ord_1_Expert', 'ord_1_Grandmaster',
#         'ord_1_Master', 'ord_1_Novice', 'ord_2_Boiling Hot', 'ord_2_Cold',
#         'ord_2_Freezing', 'ord_2_Hot', 'ord_2_Lava Hot', 'ord_2_Warm',
#         'nom_0_FE', 'nom_1_FE', 'nom_2_FE', 'nom_3_FE', 'nom_4_FE', 'nom_9_FE',
#         'ord_3_FE', 'ord_4_FE'],
#        dtype='object'),
#  Index(['id', 'nom_0', 'nom_1', 'nom_2', 'nom_3', 'nom_4', 'nom_5', 'nom_6',
#         'nom_7', 'nom_8', 'nom_9', 'ord_3', 'ord_4', 'ord_5', 'day', 'month',
#         'nom_5_month_count', 'nom_6_month_count', 'nom_7_month_count',
#         'nom_8_month_count', 'ord_5_month_count', 'bin_0_0', 'bin_0_1',
#         'bin_1_0', 'bin_1_1', 'bin_2_0', 'bin_2_1', 'bin_3_F', 'bin_3_T',
#         'bin_4_N', 'bin_4_Y', 'ord_0_1', 'ord_0_2', 'ord_0_3',
#         'ord_1_Contributor', 'ord_1_Expert', 'ord_1_Grandmaster',
#         'ord_1_Master', 'ord_1_Novice', 'ord_2_Boiling Hot', 'ord_2_Cold',
#         'ord_2_Freezing', 'ord_2_Hot', 'ord_2_Lava Hot', 'ord_2_Warm',
#         'nom_0_FE', 'nom_1_FE', 'nom_2_FE', 'nom_3_FE', 'nom_4_FE', 'nom_9_FE',
#         'ord_3_FE', 'ord_4_FE'],
#        dtype='object'))

# %%
# test.isnull().any()

# %%
train.head()
# Out:
#    id      nom_5      nom_6      nom_7      nom_8 ord_5  day  month  \
# 0   0  50f116bcf  3ac1b8814  68f6ad3e9  c389000ab    kr    2      2
# 1   1  b3b4d25d0  fbcb50fc1  3b6dd5612  4cd920251    bF    7      8
# 2   2  3263bdce5  0922e3cb8  a6a36f527  de9c9f684    Jc    7      2
# 3   3  f12246592  50d7ad46a  ec69236eb  4ade6ab69    kW    2      1
# 4   4  5b0f5acd5  1fe17a1fd  04ddac2be  cb43ab175    qP    7      8
#
#    nom_5_month_count  nom_6_month_count    ...     ord_2_Lava Hot  ord_2_Warm  \
# 0                399                176    ...                  0           0
# 1                 55                 51    ...                  0           0
# 2                389                212    ...                  1           0
# 3                123                150    ...                  0           0
# 4                144                 65    ...                  0           0
#
#    nom_0_FE  nom_1_FE  nom_2_FE  nom_3_FE  nom_4_FE  nom_9_FE  ord_3_FE  \
# 0       0.0       5.0       2.0       3.0       2.0    7446.0       5.0
# 1       0.0       0.0       5.0       0.0       1.0    8802.0       2.0
# 2       1.0       0.0       0.0       0.0       3.0    4796.0       5.0
# 3       2.0       0.0       2.0       1.0       0.0    1405.0       4.0
# 4       2.0       0.0       0.0       1.0       0.0    3423.0       2.0
#
#    ord_4_FE
# 0      22.0
# 1       3.0
# 2       4.0
# 3      22.0
# 4       4.0
#
# [5 rows x 45 columns]

# %%
ce_cols
# Out:
# ['nom_0', 'nom_1', 'nom_2', 'nom_3', 'nom_4', 'nom_9', 'ord_3', 'ord_4']

# %%
train=train.drop(columns=ce_cols+['nom_5','nom_6','nom_7','nom_8','ord_5'],axis=1)
test=test.drop(columns=ce_cols+['nom_5','nom_6','nom_7','nom_8','ord_5'],axis=1)

# %%
train=train.drop(columns=['nom_5','nom_6','nom_7','nom_8','ord_5'],axis=1)
test=test.drop(columns=['nom_5','nom_6','nom_7','nom_8','ord_5'],axis=1)

# %%
# plt.figure(figsize=(30,30))
# sns.heatmap(train[feats].corr(), cmap='RdBu_r', annot=True, center=0.0)

# %% [markdown]
# ### Modelling

# %%
##https://www.kaggle.com/kyakovlev/ieee-fe-for-local-test
def seed_everything(seed=0):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

# %%
seed_everything(1001)

# %%
##import required libraries:
from sklearn.model_selection import StratifiedKFold,GroupKFold
import lightgbm as lgb
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score,roc_curve
from sklearn.linear_model import LogisticRegression
import gc
from tqdm import tqdm
#import lofo as lofo

# %%
## Split into train and validation:
y=train['target']
train.drop('target',axis=1,inplace=True)

# %%
n_folds=5
kf=StratifiedKFold(n_splits=n_folds,shuffle=True,random_state=1001)
feats=[f for f in train.columns if f not in ['id','bin_0_1',
 'bin_1_1',
 'bin_2_0',
 'bin_3_F',
 'bin_4_N']]

# %%
oof_preds=np.zeros(train.shape[0])
sub_preds=np.zeros(test.shape[0])

feature_importance_df=pd.DataFrame()
categorical_features=[f for f in train.columns if f not in ['id','bin_0_1',
 'bin_1_1',
 'bin_2_0',
 'bin_3_F',
 'bin_4_N']]

# %%
categorical_features
# Out:
# ['day',
#  'month',
#  'nom_5_month_count',
#  'nom_6_month_count',
#  'nom_7_month_count',
#  'nom_8_month_count',
#  'ord_5_month_count',
#  'bin_0_0',
#  'bin_1_0',
#  'bin_2_1',
#  'bin_3_T',
#  'bin_4_Y',
#  'ord_0_1',
#  'ord_0_2',
#  'ord_0_3',
#  'ord_1_Contributor',
#  'ord_1_Expert',
#  'ord_1_Grandmaster',
#  'ord_1_Master',
#  'ord_1_Novice',
#  'ord_2_Boiling Hot',
#  'ord_2_Cold',
#  'ord_2_Freezing',
#  'ord_2_Hot',
#  'ord_2_Lava Hot',
#  'ord_2_Warm',
#  'nom_0_FE',
#  'nom_1_FE',
#  'nom_2_FE',
#  'nom_3_FE',
#  'nom_4_FE',
#  'nom_9_FE',
#  'ord_3_FE',
#  'ord_4_FE']

# %%
##https://www.kaggle.com/cdeotte/eda-for-columns-v-and-id
plt.figure(figsize=(30,30))
sns.heatmap(train[feats].corr(), cmap='RdBu_r', annot=True, center=0.0)

# %%
cor=train[feats].corr()

# %%
##https://www.kaggle.com/gpreda/santander-eda-and-prediction
c=cor.unstack()
so=c.sort_values(kind='quicksort').reset_index().rename({0:'value'},axis=1)
so=so[so['level_0']!=so['level_1']]
print("Negative correlated features \n",so.head(10),"\nPositive correlated features\n",so.tail(10))
# Out:
# Negative correlated features
#               level_0            level_1     value
# 0            ord_0_2            ord_0_1 -0.726006
# 1            ord_0_1            ord_0_2 -0.726006
# 2            ord_0_3            ord_0_1 -0.523988
# 3            ord_0_1            ord_0_3 -0.523988
# 4       ord_1_Novice  ord_1_Grandmaster -0.503913
# 5  ord_1_Grandmaster       ord_1_Novice -0.503913
# 6              month  ord_5_month_count -0.475910
# 7  ord_5_month_count              month -0.475910
# 8              month  nom_5_month_count -0.470987
# 9  nom_5_month_count              month -0.470987
# Positive correlated features
#                  level_0            level_1     value
# 1112  ord_5_month_count  nom_7_month_count  0.411375
# 1113  nom_7_month_count  ord_5_month_count  0.411375
# 1114  nom_6_month_count  nom_7_month_count  0.411752
# 1115  nom_7_month_count  nom_6_month_count  0.411752
# 1116  nom_5_month_count  nom_6_month_count  0.415743
# 1117  nom_6_month_count  nom_5_month_count  0.415743
# 1118  nom_5_month_count  ord_5_month_count  0.418853
# 1119  ord_5_month_count  nom_5_month_count  0.418853
# 1120  nom_6_month_count  ord_5_month_count  0.420894
# 1121  ord_5_month_count  nom_6_month_count  0.420894

# %% [markdown]
# * From the above correlation plot it is seen that the summary features correlate with their respective FE variables.Ord_0_1 , ord_0_2 and ord_0_3 show correlation with each other.

# %%
#Parameters through Bayesian Optimization:

param = {'num_leaves': 40,
         'min_data_in_leaf': 69, 
         'objective':'binary',
         'max_depth': 4,
         'learning_rate': 0.026,
         "boosting": "gbdt",
         "feature_fraction": 0.49,
         "metric": 'auc',
         "lambda_l2": 2.84,
         "random_state": 100,
         "min_gain_to_split":0.386,
         "bagging_freq":5, ## randomly initialized
         "bagging_fraction":0.5,## randomly initialized
         "verbosity": -1}

# {'feature_fraction': 0.49667591307631404,
#  'lambda_l2': 2.843966944905738,
#  'learning_rate': 0.026747986947564972,
#  'max_depth': 4.390096819896572,
#  'min_data_in_leaf': 68.92767604826321,
#  'min_gain_to_split': 0.38669168478099314,
#  'num_leaves': 39.828939074908384}

# param = {'num_leaves': 60,
#          'min_data_in_leaf': 60, 
#          'objective':'binary',
#          'max_depth': -1,
#          'learning_rate': 0.1,
#          "boosting": "gbdt",
#          "feature_fraction": 0.8,
#          "bagging_freq": 1,
#          "bagging_fraction": 0.8 ,
#          "bagging_seed": 11,
#          "metric": 'auc',
#          "lambda_l1": 0.1,
#          "random_state": 133,
#          "verbosity": -1}

# %%
# ## Feature importance:

# dataset=lofo.Dataset(df=train,target="target",features=categorical_features)

# lgbm=lgb.train(param,num_round,
#                     verbose_eval=100,
#                     early_stopping_rounds = 200)

# lf=LOFOImportance(dataset,model=lgbm,cv=4,scoring='roc_auc',n_jobs=4)

# # dataset = Dataset(df=df, target="binary_target", features=features, feature_groups=feature_groups)

# # lgbm = LGBMClassifier(random_state=0, n_jobs=1)

# # lofo = LOFOImportance(dataset, model=lgbm, cv=4, scoring='roc_auc', n_jobs=4)

# %%
## Using the standard cross validation format for training.


for n_folds,(train_idx,valid_idx) in tqdm(enumerate(kf.split(train.values,y.values))):
    print("fold n°{}".format(n_folds+1))
    trn_data = lgb.Dataset(train.iloc[train_idx][feats],
                           label=y.iloc[train_idx],
                           categorical_feature=categorical_features
                          )
    val_data = lgb.Dataset(train.iloc[valid_idx][feats],
                           label=y.iloc[valid_idx],categorical_feature=categorical_features
                          )

    num_round = 10000
    clf = lgb.train(param,
                    trn_data,
                    num_round,
                    valid_sets = [trn_data, val_data],
                    verbose_eval=100,
                    early_stopping_rounds = 200)
    oof_preds[valid_idx]=clf.predict(train.iloc[valid_idx][feats],num_iteration=clf.best_iteration)
    sub_preds+=clf.predict(test[feats],num_iteration=clf.best_iteration)/kf.n_splits
    
    fold_importance_df=pd.DataFrame()
    fold_importance_df['features']=feats
    fold_importance_df['importance']=clf.feature_importance(importance_type='gain')
    fold_importance_df['folds']=n_folds+1
    print(f'Fold {n_folds+1}: Most important features are:\n')
    for i in np.argsort(fold_importance_df['importance'])[-5:]:
        print(f'{fold_importance_df.iloc[i,0]}-->{fold_importance_df.iloc[i,1]}')
    
    feature_importance_df=pd.concat([feature_importance_df,fold_importance_df],axis=0)
    
    print('Fold %2d AUC : %.6f' % (n_folds + 1, roc_auc_score(y.iloc[valid_idx], oof_preds[valid_idx])))
    del clf
    gc.collect()
    


print('Full auc score %.6f' % (roc_auc_score(y,oof_preds)))

test['target']=sub_preds
# Out:
# 0it [00:00, ?it/s]
# fold n°1
# C:\Users\deepa\Miniconda3\lib\site-packages\lightgbm\basic.py:1205: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# C:\Users\deepa\Miniconda3\lib\site-packages\lightgbm\basic.py:762: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.742282	valid_1's auc: 0.728725
# [200]	training's auc: 0.7637	valid_1's auc: 0.741127
# [300]	training's auc: 0.77583	valid_1's auc: 0.745858
# [400]	training's auc: 0.784436	valid_1's auc: 0.748119
# [500]	training's auc: 0.790789	valid_1's auc: 0.74941
# [600]	training's auc: 0.795868	valid_1's auc: 0.74956
# [700]	training's auc: 0.800809	valid_1's auc: 0.749799
# [800]	training's auc: 0.804349	valid_1's auc: 0.749636
# Early stopping, best iteration is:
# [641]	training's auc: 0.798103	valid_1's auc: 0.749981
# Fold 1: Most important features are:
#
# ord_3_FE-->45529.995746552944
# ord_4_FE-->67663.87322878838
# nom_5_month_count-->82587.00643837452
# ord_5_month_count-->104325.33771657944
# nom_9_FE-->107375.82919311523
# Fold  1 AUC : 0.749981
# 1it [01:26, 86.58s/it]
# fold n°2
# C:\Users\deepa\Miniconda3\lib\site-packages\lightgbm\basic.py:1205: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# C:\Users\deepa\Miniconda3\lib\site-packages\lightgbm\basic.py:762: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.74402	valid_1's auc: 0.718194
# [200]	training's auc: 0.765443	valid_1's auc: 0.731323
# [300]	training's auc: 0.776982	valid_1's auc: 0.735763
# [400]	training's auc: 0.785917	valid_1's auc: 0.738425
# [500]	training's auc: 0.792507	valid_1's auc: 0.739695
# [600]	training's auc: 0.797895	valid_1's auc: 0.740374
# [700]	training's auc: 0.802646	valid_1's auc: 0.740681
# [800]	training's auc: 0.806519	valid_1's auc: 0.740755
# [900]	training's auc: 0.809672	valid_1's auc: 0.74066
# Early stopping, best iteration is:
# [791]	training's auc: 0.806249	valid_1's auc: 0.740811
# Fold 2: Most important features are:
#
# nom_6_month_count-->47434.66816085577
# ord_4_FE-->71366.99315345287
# nom_5_month_count-->90457.6065954119
# ord_5_month_count-->117753.69220328331
# nom_9_FE-->141577.28580474854
# Fold  2 AUC : 0.740811
# 2it [03:04, 90.13s/it]
# fold n°3
# C:\Users\deepa\Miniconda3\lib\site-packages\lightgbm\basic.py:1205: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# C:\Users\deepa\Miniconda3\lib\site-packages\lightgbm\basic.py:762: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.742959	valid_1's auc: 0.727277
# [200]	training's auc: 0.764418	valid_1's auc: 0.73945
# [300]	training's auc: 0.776012	valid_1's auc: 0.743851
# [400]	training's auc: 0.784803	valid_1's auc: 0.745935
# [500]	training's auc: 0.791324	valid_1's auc: 0.747252
# [600]	training's auc: 0.796416	valid_1's auc: 0.747826
# [700]	training's auc: 0.801248	valid_1's auc: 0.748058
# [800]	training's auc: 0.804863	valid_1's auc: 0.748339
# [900]	training's auc: 0.80828	valid_1's auc: 0.748569
# [1000]	training's auc: 0.811739	valid_1's auc: 0.748399
# [1100]	training's auc: 0.81481	valid_1's auc: 0.748129
# Early stopping, best iteration is:
# [900]	training's auc: 0.80828	valid_1's auc: 0.748569
# Fold 3: Most important features are:
#
# nom_6_month_count-->54652.999264001846
# ord_4_FE-->68271.07218259573
# nom_5_month_count-->93959.90608376265
# ord_5_month_count-->119557.41076868773
# nom_9_FE-->162364.47386932373
# Fold  3 AUC : 0.748569
# 3it [04:53, 95.51s/it]
# fold n°4
# C:\Users\deepa\Miniconda3\lib\site-packages\lightgbm\basic.py:1205: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# C:\Users\deepa\Miniconda3\lib\site-packages\lightgbm\basic.py:762: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.743289	valid_1's auc: 0.725345
# [200]	training's auc: 0.764482	valid_1's auc: 0.737154
# [300]	training's auc: 0.776322	valid_1's auc: 0.741144
# [400]	training's auc: 0.785036	valid_1's auc: 0.743368
# [500]	training's auc: 0.791525	valid_1's auc: 0.744759
# [600]	training's auc: 0.797007	valid_1's auc: 0.745188
# [700]	training's auc: 0.801796	valid_1's auc: 0.745532
# [800]	training's auc: 0.805507	valid_1's auc: 0.745493
# [900]	training's auc: 0.808991	valid_1's auc: 0.745545
# Early stopping, best iteration is:
# [742]	training's auc: 0.803503	valid_1's auc: 0.745743
# Fold 4: Most important features are:
#
# ord_3_FE-->46378.46701285243
# ord_4_FE-->68742.93214207888
# nom_5_month_count-->84929.10469257832
# ord_5_month_count-->112458.6354187131
# nom_9_FE-->130990.49003601074
# Fold  4 AUC : 0.745743
# 4it [06:26, 94.96s/it]
# fold n°5
# C:\Users\deepa\Miniconda3\lib\site-packages\lightgbm\basic.py:1205: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# C:\Users\deepa\Miniconda3\lib\site-packages\lightgbm\basic.py:762: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.742402	valid_1's auc: 0.727742
# [200]	training's auc: 0.764738	valid_1's auc: 0.740275
# [300]	training's auc: 0.776125	valid_1's auc: 0.744231
# [400]	training's auc: 0.784495	valid_1's auc: 0.74622
# [500]	training's auc: 0.791177	valid_1's auc: 0.747399
# [600]	training's auc: 0.796549	valid_1's auc: 0.74766
# [700]	training's auc: 0.801187	valid_1's auc: 0.747639
# Early stopping, best iteration is:
# [564]	training's auc: 0.794894	valid_1's auc: 0.747823
# Fold 5: Most important features are:
#
# ord_3_FE-->45208.29786109924
# ord_4_FE-->63934.87199866772
# nom_5_month_count-->73586.40700362623
# nom_9_FE-->90740.24668121338
# ord_5_month_count-->98827.81222057343
# Fold  5 AUC : 0.747823
# 5it [07:42, 92.48s/it]
# Full auc score 0.746472

# %% [markdown]
# * The local cv score increases by 0.000865 when we include only one of the categories in binary cardinality features and leave out using combination of features.The score was .793503 whereas including all the features the score was 0.792638.
# * After doing the summary features only for certain columns the local auc score is 0.792114 which is not a improvement over the above which gave a local cv score of 0.793503.Therefore we retain the above score.

# %% [markdown]
# **To try out**
#
# * Remove either the summary features or the FE features of the correlated variables and see if the score increases or decreases.
#
# * Do a summary features of most important columns https://www.kaggle.com/tunguz/elo-adversarial-validation

# %%
# ##https://www.kaggle.com/cdeotte/xgb-fraud-with-magic-0-9600
# kf=GroupKFold(n_splits=12)

# %%
# ## Using the standard cross validation format for training.


# for n_folds,(train_idx,valid_idx) in tqdm(enumerate(kf.split(train.values,y.values,groups=train['month']))):
    
#     print("fold n°{}".format(n_folds+1))
#     month = train.iloc[valid_idx]['month'].iloc[0]
#     print('\nFold',n_folds+1,'withholding month',month)
#     print('\n rows of train =',len(train_idx),'rows of holdout =',len(valid_idx))
#     trn_data = lgb.Dataset(train.iloc[train_idx][feats],
#                            label=y.iloc[train_idx],
#                            categorical_feature=categorical_features
#                           )
#     val_data = lgb.Dataset(train.iloc[valid_idx][feats],
#                            label=y.iloc[valid_idx],categorical_feature=categorical_features
#                           )

#     num_round = 10000
#     clf = lgb.train(param,
#                     trn_data,
#                     num_round,
#                     valid_sets = [trn_data, val_data],
#                     verbose_eval=100,
#                     early_stopping_rounds = 200)
#     oof_preds[valid_idx]=clf.predict(train.iloc[valid_idx][feats],num_iteration=clf.best_iteration)
#     sub_preds+=clf.predict(test[feats],num_iteration=clf.best_iteration)/kf.n_splits
    
#     fold_importance_df=pd.DataFrame()
#     fold_importance_df['features']=feats
#     fold_importance_df['importance']=clf.feature_importance(importance_type='gain')
#     fold_importance_df['folds']=n_folds+1
#     print(f'Fold {n_folds+1}: Most important features are:\n')
#     for i in np.argsort(fold_importance_df['importance'])[-5:]:
#         print(f'{fold_importance_df.iloc[i,0]}-->{fold_importance_df.iloc[i,1]}')
    
#     feature_importance_df=pd.concat([feature_importance_df,fold_importance_df],axis=0)
    
#     print('Fold %2d AUC : %.6f' % (n_folds + 1, roc_auc_score(y.iloc[valid_idx], oof_preds[valid_idx])))
#     del clf
#     gc.collect()
    


# print('Full auc score %.6f' % (roc_auc_score(y,oof_preds)))

# test['target']=sub_preds

# %%
# ## Random Forest
# for n_folds,(train_idx,valid_idx) in tqdm(enumerate(kf.split(train.values,y.values))):
#     print("fold n°{}".format(n_folds+1))
#     trn_X = train.iloc[train_idx][feats]
#     trn_Y = y.iloc[train_idx]
#     val_X=train.iloc[valid_idx][feats]
#     val_Y=y.iloc[valid_idx]
#     num_round = 10000
#     clf =RandomForestClassifier(n_estimators=50,min_samples_split=10,min_samples_leaf=10,max_depth=10,random_state=100,criterion='gini',max_features='sqrt',oob_score=True)
#     clf.fit(trn_X,trn_Y)
#     oof_preds[valid_idx]=clf.predict(train.iloc[valid_idx][feats])
#     sub_preds+=clf.predict(test[feats])/kf.n_splits
    
#     fold_importance_df=pd.DataFrame()
#     fold_importance_df['features']=feats
#     fold_importance_df['importance']=clf.feature_importances_
#     fold_importance_df['folds']=n_folds+1
#     print(f'Fold {n_folds+1}: Most important features are:\n')
#     for i in np.argsort(fold_importance_df['importance'])[-5:]:
#         print(f'{fold_importance_df.iloc[i,0]}-->{fold_importance_df.iloc[i,1]}')
    
#     feature_importance_df=pd.concat([feature_importance_df,fold_importance_df],axis=0)
    
#     print('Fold %2d AUC : %.6f' % (n_folds + 1, roc_auc_score(y.iloc[valid_idx], oof_preds[valid_idx])))
#     del clf
#     gc.collect()
    


# print('Full auc score %.6f' % (roc_auc_score(y,oof_preds)))

# test['target']=sub_preds

# %%
sample['target']=sub_preds

# %%
sample.head()
# Out:
#        id    target
# 0  300000  0.376683
# 1  300001  0.594446
# 2  300002  0.324825
# 3  300003  0.568067
# 4  300004  0.713771

# %%
sample.to_csv("sample_submission.csv",index=False)
